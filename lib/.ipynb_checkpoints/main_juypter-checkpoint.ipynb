# %%
from step_parse import StepParse

# step_filename = 'C:/Users/prctha/Desktop/Torch Assembly.STEP'
step_filename = '../examples/models/Model00001.stp'
test = StepParse()

test.load_step(step_filename)

# test.create_tree()
test.print_tree()

test.tree_to_json()
# Out:
# ["#583=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Perfil canal U:1','Perfil canal U:1','Perfil canal U:1',#51,#90,'Perfil canal U:1');", "#595=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Perfil canal U:2','Perfil canal U:2','Perfil canal U:2',#51,#90,'Perfil canal U:2');", "#1095=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Canal largo:1','Canal largo:1','Canal largo:1',#51,#610,'Canal largo:1');", "#1107=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Canal largo:2','Canal largo:2','Canal largo:2',#51,#610,'Canal largo:2');", "#1956=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Tuerca hexagonal - Pulgadas 1 - 8:1','Tuerca hexagonal - Pulgadas 1 - 8:1','Tuerca hexagonal - Pulgadas 1 - 8:1',#51,#1122,'Tuerca hexagonal - Pulgadas 1 - 8:1');", "#1968=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Tuerca hexagonal - Pulgadas 1 - 8:2','Tuerca hexagonal - Pulgadas 1 - 8:2','Tuerca hexagonal - Pulgadas 1 - 8:2',#51,#1122,'Tuerca hexagonal - Pulgadas 1 - 8:2');", "#1980=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Tuerca hexagonal - Pulgadas 1 - 8:3','Tuerca hexagonal - Pulgadas 1 - 8:3','Tuerca hexagonal - Pulgadas 1 - 8:3',#51,#1122,'Tuerca hexagonal - Pulgadas 1 - 8:3');", "#1992=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Tuerca hexagonal - Pulgadas 1 - 8:4','Tuerca hexagonal - Pulgadas 1 - 8:4','Tuerca hexagonal - Pulgadas 1 - 8:4',#51,#1122,'Tuerca hexagonal - Pulgadas 1 - 8:4');", "#2158=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Esparrago:1','Esparrago:1','Esparrago:1',#51,#2007,'Esparrago:1');", "#2170=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Esparrago:2','Esparrago:2','Esparrago:2',#51,#2007,'Esparrago:2');", "#2182=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Esparrago:3','Esparrago:3','Esparrago:3',#51,#2007,'Esparrago:3');", "#2194=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Esparrago:4','Esparrago:4','Esparrago:4',#51,#2007,'Esparrago:4');", "#2441=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Pata:1','Pata:1','Pata:1',#51,#2209,'Pata:1');", "#2453=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Tuerca hexagonal - Pulgadas 1 - 8:5','Tuerca hexagonal - Pulgadas 1 - 8:5','Tuerca hexagonal - Pulgadas 1 - 8:5',#51,#1122,'Tuerca hexagonal - Pulgadas 1 - 8:5');", "#2465=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Pata:2','Pata:2','Pata:2',#51,#2209,'Pata:2');", "#2477=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Pata:3','Pata:3','Pata:3',#51,#2209,'Pata:3');", "#2489=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Pata:4','Pata:4','Pata:4',#51,#2209,'Pata:4');", "#2989=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Columna chumaceras:1','Columna chumaceras:1','Columna chumaceras:1',#51,#2504,'Columna chumaceras:1');", "#3285=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Placa base chumacera:1','Placa base chumacera:1','Placa base chumacera:1',#51,#3004,'Placa base chumacera:1');", "#3297=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Columna chumaceras:2','Columna chumaceras:2','Columna chumaceras:2',#51,#2504,'Columna chumaceras:2');", "#3309=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Columna chumaceras:3','Columna chumaceras:3','Columna chumaceras:3',#51,#2504,'Columna chumaceras:3');", "#3321=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Columna chumaceras:4','Columna chumaceras:4','Columna chumaceras:4',#51,#2504,'Columna chumaceras:4');", "#3333=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Placa base chumacera:2','Placa base chumacera:2','Placa base chumacera:2',#51,#3004,'Placa base chumacera:2');", "#3345=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Placa base chumacera:3','Placa base chumacera:3','Placa base chumacera:3',#51,#3004,'Placa base chumacera:3');", "#3357=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Placa base chumacera:4','Placa base chumacera:4','Placa base chumacera:4',#51,#3004,'Placa base chumacera:4');", "#3857=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Canal larguero girador:1','Canal larguero girador:1','Canal larguero girador:1',#51,#3372,'Canal larguero girador:1');", "#3869=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Canal larguero girador:2','Canal larguero girador:2','Canal larguero girador:2',#51,#3372,'Canal larguero girador:2');", "#4375=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Placa soporte girador:1','Placa soporte girador:1','Placa soporte girador:1',#51,#3884,'Placa soporte girador:1');", "#4637=NEXT_ASSEMBLY_USAGE_OCCURRENCE('Placa soporte pi ...
# ["#12=PRODUCT_DEFINITION('',$,#10,#11);", "#51=PRODUCT_DEFINITION('',$,#49,#50);", "#90=PRODUCT_DEFINITION('',$,#88,#89);", "#610=PRODUCT_DEFINITION('',$,#608,#609);", "#1122=PRODUCT_DEFINITION('',$,#1120,#1121);", "#2007=PRODUCT_DEFINITION('',$,#2005,#2006);", "#2209=PRODUCT_DEFINITION('',$,#2207,#2208);", "#2504=PRODUCT_DEFINITION('',$,#2502,#2503);", "#3004=PRODUCT_DEFINITION('',$,#3002,#3003);", "#3372=PRODUCT_DEFINITION('',$,#3370,#3371);", "#3884=PRODUCT_DEFINITION('',$,#3882,#3883);", "#4390=PRODUCT_DEFINITION('',$,#4388,#4389);", "#4688=PRODUCT_DEFINITION('',$,#4686,#4687);", "#5303=PRODUCT_DEFINITION('',$,#5301,#5302);", "#5661=PRODUCT_DEFINITION('',$,#5659,#5660);", "#5901=PRODUCT_DEFINITION('',$,#5899,#5900);", "#6267=PRODUCT_DEFINITION('',$,#6265,#6266);", "#6612=PRODUCT_DEFINITION('',$,#6610,#6611);", "#7196=PRODUCT_DEFINITION('',$,#7194,#7195);", "#7756=PRODUCT_DEFINITION('',$,#7754,#7755);", "#8544=PRODUCT_DEFINITION('',$,#8542,#8543);", "#8763=PRODUCT_DEFINITION('',$,#8761,#8762);", "#8802=PRODUCT_DEFINITION('',$,#8800,#8801);", "#8962=PRODUCT_DEFINITION('',$,#8960,#8961);", "#9223=PRODUCT_DEFINITION('',$,#9221,#9222);", "#9558=PRODUCT_DEFINITION('',$,#9556,#9557);", "#9822=PRODUCT_DEFINITION('',$,#9820,#9821);", "#10084=PRODUCT_DEFINITION('',$,#10082,#10083);", "#10363=PRODUCT_DEFINITION('',$,#10361,#10362);", "#10402=PRODUCT_DEFINITION('',$,#10400,#10401);", "#11058=PRODUCT_DEFINITION('',$,#11056,#11057);", "#11714=PRODUCT_DEFINITION('',$,#11712,#11713);", "#12394=PRODUCT_DEFINITION('',$,#12392,#12393);", "#12724=PRODUCT_DEFINITION('',$,#12722,#12723);", "#12884=PRODUCT_DEFINITION('',$,#12882,#12883);", "#13184=PRODUCT_DEFINITION('',$,#13182,#13183);", "#13541=PRODUCT_DEFINITION('',$,#13539,#13540);", "#13772=PRODUCT_DEFINITION('',$,#13770,#13771);", "#14179=PRODUCT_DEFINITION('',$,#14177,#14178);", "#14557=PRODUCT_DEFINITION('',$,#14555,#14556);", "#14836=PRODUCT_DEFINITION('',$,#14834,#14835);", "#15300=PRODUCT_DEFINITION('',$,#15298,#15299);", "#15339=PRODUCT_DEFINITION('',$,#15337,#15338);", "#22532=PRODUCT_DEFINITION('',$,#22530,#22531);", "#23782=PRODUCT_DEFINITION('',$,#23780,#23781);", "#24057=PRODUCT_DEFINITION('',$,#24055,#24056);", "#24096=PRODUCT_DEFINITION('',$,#24094,#24095);", "#24639=PRODUCT_DEFINITION('',$,#24637,#24638);", "#24678=PRODUCT_DEFINITION('',$,#24676,#24677);", "#25016=PRODUCT_DEFINITION('',$,#25014,#25015);", "#27128=PRODUCT_DEFINITION('',$,#27126,#27127);", "#27428=PRODUCT_DEFINITION('',$,#27426,#27427);", "#27601=PRODUCT_DEFINITION('',$,#27599,#27600);", "#27779=PRODUCT_DEFINITION('',$,#27777,#27778);", "#27914=PRODUCT_DEFINITION('',$,#27912,#27913);", "#27953=PRODUCT_DEFINITION('',$,#27951,#27952);", "#27992=PRODUCT_DEFINITION('',$,#27990,#27991);", "#28780=PRODUCT_DEFINITION('',$,#28778,#28779);", "#29296=PRODUCT_DEFINITION('',$,#29294,#29295);", "#29335=PRODUCT_DEFINITION('',$,#29333,#29334);", "#29945=PRODUCT_DEFINITION('',$,#29943,#29944);", "#30189=PRODUCT_DEFINITION('',$,#30187,#30188);", "#30228=PRODUCT_DEFINITION('',$,#30226,#30227);", "#30765=PRODUCT_DEFINITION('',$,#30763,#30764);", "#30996=PRODUCT_DEFINITION('',$,#30994,#30995);", "#31400=PRODUCT_DEFINITION('',$,#31398,#31399);", "#32458=PRODUCT_DEFINITION('',$,#32456,#32457);", "#32686=PRODUCT_DEFINITION('',$,#32684,#32685);", "#32905=PRODUCT_DEFINITION('',$,#32903,#32904);", "#32944=PRODUCT_DEFINITION('',$,#32942,#32943);", "#34323=PRODUCT_DEFINITION('',$,#34321,#34322);", "#34744=PRODUCT_DEFINITION('',$,#34742,#34743);", "#34783=PRODUCT_DEFINITION('',$,#34781,#34782);", "#34950=PRODUCT_DEFINITION('',$,#34948,#34949);", "#35122=PRODUCT_DEFINITION('',$,#35120,#35121);", "#35161=PRODUCT_DEFINITION('',$,#35159,#35160);", "#35743=PRODUCT_DEFINITION('',$,#35741,#35742);", "#43405=PRODUCT_DEFINITION('',$,#43403,#43404);", "#43444=PRODUCT_DEFINITION('',$,#43442,#43443);", "#43796=PRODUCT_DEFINITION('',$,#43794,#43795);", "#43835=PRODUCT_DEFINITION('',$,#43833,#43834);", "#44043=PRODUCT_DEFINITION('',$,#44041,#44042);", " ...
# ["#10=PRODUCT_DEFINITION_FORMATION('',$,#8);", "#49=PRODUCT_DEFINITION_FORMATION('',$,#47);", "#88=PRODUCT_DEFINITION_FORMATION('',$,#86);", "#608=PRODUCT_DEFINITION_FORMATION('',$,#606);", "#1120=PRODUCT_DEFINITION_FORMATION('',$,#1118);", "#2005=PRODUCT_DEFINITION_FORMATION('',$,#2003);", "#2207=PRODUCT_DEFINITION_FORMATION('',$,#2205);", "#2502=PRODUCT_DEFINITION_FORMATION('',$,#2500);", "#3002=PRODUCT_DEFINITION_FORMATION('',$,#3000);", "#3370=PRODUCT_DEFINITION_FORMATION('',$,#3368);", "#3882=PRODUCT_DEFINITION_FORMATION('',$,#3880);", "#4388=PRODUCT_DEFINITION_FORMATION('',$,#4386);", "#4686=PRODUCT_DEFINITION_FORMATION('',$,#4684);", "#5301=PRODUCT_DEFINITION_FORMATION('',$,#5299);", "#5659=PRODUCT_DEFINITION_FORMATION('',$,#5657);", "#5899=PRODUCT_DEFINITION_FORMATION('',$,#5897);", "#6265=PRODUCT_DEFINITION_FORMATION('',$,#6263);", "#6610=PRODUCT_DEFINITION_FORMATION('',$,#6608);", "#7194=PRODUCT_DEFINITION_FORMATION('',$,#7192);", "#7754=PRODUCT_DEFINITION_FORMATION('',$,#7752);", "#8542=PRODUCT_DEFINITION_FORMATION('',$,#8540);", "#8761=PRODUCT_DEFINITION_FORMATION('',$,#8759);", "#8800=PRODUCT_DEFINITION_FORMATION('',$,#8798);", "#8960=PRODUCT_DEFINITION_FORMATION('',$,#8958);", "#9221=PRODUCT_DEFINITION_FORMATION('',$,#9219);", "#9556=PRODUCT_DEFINITION_FORMATION('',$,#9554);", "#9820=PRODUCT_DEFINITION_FORMATION('',$,#9818);", "#10082=PRODUCT_DEFINITION_FORMATION('',$,#10080);", "#10361=PRODUCT_DEFINITION_FORMATION('',$,#10359);", "#10400=PRODUCT_DEFINITION_FORMATION('',$,#10398);", "#11056=PRODUCT_DEFINITION_FORMATION('',$,#11054);", "#11712=PRODUCT_DEFINITION_FORMATION('',$,#11710);", "#12392=PRODUCT_DEFINITION_FORMATION('',$,#12390);", "#12722=PRODUCT_DEFINITION_FORMATION('',$,#12720);", "#12882=PRODUCT_DEFINITION_FORMATION('',$,#12880);", "#13182=PRODUCT_DEFINITION_FORMATION('',$,#13180);", "#13539=PRODUCT_DEFINITION_FORMATION('',$,#13537);", "#13770=PRODUCT_DEFINITION_FORMATION('',$,#13768);", "#14177=PRODUCT_DEFINITION_FORMATION('',$,#14175);", "#14555=PRODUCT_DEFINITION_FORMATION('',$,#14553);", "#14834=PRODUCT_DEFINITION_FORMATION('',$,#14832);", "#15298=PRODUCT_DEFINITION_FORMATION('',$,#15296);", "#15337=PRODUCT_DEFINITION_FORMATION('',$,#15335);", "#22530=PRODUCT_DEFINITION_FORMATION('',$,#22528);", "#23780=PRODUCT_DEFINITION_FORMATION('',$,#23778);", "#24055=PRODUCT_DEFINITION_FORMATION('',$,#24053);", "#24094=PRODUCT_DEFINITION_FORMATION('',$,#24092);", "#24637=PRODUCT_DEFINITION_FORMATION('',$,#24635);", "#24676=PRODUCT_DEFINITION_FORMATION('',$,#24674);", "#25014=PRODUCT_DEFINITION_FORMATION('',$,#25012);", "#27126=PRODUCT_DEFINITION_FORMATION('',$,#27124);", "#27426=PRODUCT_DEFINITION_FORMATION('',$,#27424);", "#27599=PRODUCT_DEFINITION_FORMATION('',$,#27597);", "#27777=PRODUCT_DEFINITION_FORMATION('',$,#27775);", "#27912=PRODUCT_DEFINITION_FORMATION('',$,#27910);", "#27951=PRODUCT_DEFINITION_FORMATION('',$,#27949);", "#27990=PRODUCT_DEFINITION_FORMATION('',$,#27988);", "#28778=PRODUCT_DEFINITION_FORMATION('',$,#28776);", "#29294=PRODUCT_DEFINITION_FORMATION('',$,#29292);", "#29333=PRODUCT_DEFINITION_FORMATION('',$,#29331);", "#29943=PRODUCT_DEFINITION_FORMATION('',$,#29941);", "#30187=PRODUCT_DEFINITION_FORMATION('',$,#30185);", "#30226=PRODUCT_DEFINITION_FORMATION('',$,#30224);", "#30763=PRODUCT_DEFINITION_FORMATION('',$,#30761);", "#30994=PRODUCT_DEFINITION_FORMATION('',$,#30992);", "#31398=PRODUCT_DEFINITION_FORMATION('',$,#31396);", "#32456=PRODUCT_DEFINITION_FORMATION('',$,#32454);", "#32684=PRODUCT_DEFINITION_FORMATION('',$,#32682);", "#32903=PRODUCT_DEFINITION_FORMATION('',$,#32901);", "#32942=PRODUCT_DEFINITION_FORMATION('',$,#32940);", "#34321=PRODUCT_DEFINITION_FORMATION('',$,#34319);", "#34742=PRODUCT_DEFINITION_FORMATION('',$,#34740);", "#34781=PRODUCT_DEFINITION_FORMATION('',$,#34779);", "#34948=PRODUCT_DEFINITION_FORMATION('',$,#34946);", "#35120=PRODUCT_DEFINITION_FORMATION('',$,#35118);", "#35159=PRODUCT_DEFINITION_FORMATION('',$,#35157);", "#35741=PRODUCT_DEFINITION_FORMATION('', ...
# ["#8=PRODUCT('Modelo final','Modelo final',$,(#7));", "#47=PRODUCT('Base','Base',$,(#46));", "#86=PRODUCT('Perfil canal U','Perfil canal U',$,(#85));", "#606=PRODUCT('Canal largo','Canal largo',$,(#605));", "#1118=PRODUCT('Tuerca hexagonal - Pulgadas 1 - 8','Tuerca hexagonal - Pulgadas 1 - 8',$,(#1117));", "#2003=PRODUCT('Esparrago','Esparrago',$,(#2002));", "#2205=PRODUCT('Pata','Pata',$,(#2204));", "#2500=PRODUCT('Columna chumaceras','Columna chumaceras',$,(#2499));", "#3000=PRODUCT('Placa base chumacera','Placa base chumacera',$,(#2999));", "#3368=PRODUCT('Canal larguero girador','Canal larguero girador',$,(#3367));", "#3880=PRODUCT('Placa soporte girador','Placa soporte girador',$,(#3879));", "#4386=PRODUCT('Placa soporte pie','Placa soporte pie',$,(#4385));", "#4684=PRODUCT('Cartabon base','Cartabon base',$,(#4683));", "#5299=PRODUCT('Atiesador','Atiesador',$,(#5298));", "#5657=PRODUCT('Vertical','Vertical',$,(#5656));", "#5897=PRODUCT('Oreja','Oreja',$,(#5896));", "#6263=PRODUCT('Cartab\\S\\sn horizontal','Cartab\\S\\sn horizontal',$,(#6262));", "#6608=PRODUCT('Mensula columna larga chumaceras','Mensula columna larga chumaceras',$,(#6607));", "#7192=PRODUCT('Columna larga chumaceras','Columna larga chumaceras',$,(#7191));", "#7752=PRODUCT('Soporte de reductor','Soporte de reductor',$,(#7751));", "#8540=PRODUCT('Vena de soporte a reductor','Vena de soporte a reductor',$,(#8539));", "#8759=PRODUCT('Guia hembra','Guia hembra',$,(#8758));", "#8798=PRODUCT('Funda','Funda',$,(#8797));", "#8958=PRODUCT('Pie','Pie',$,(#8957));", "#9219=PRODUCT('Nylamid','Nylamid',$,(#9218));", "#9554=PRODUCT('Vena de guia hembra','Vena de guia hembra',$,(#9553));", "#9818=PRODUCT('Placa de tope','Placa de tope',$,(#9817));", "#10080=PRODUCT('Vena del tope','Vena del tope',$,(#10079));", "#10359=PRODUCT('Cruzeta','Cruzeta',$,(#10358));", "#10398=PRODUCT('Seccion larga','Seccion larga',$,(#10397));", "#11054=PRODUCT('Seccion corta','Seccion corta',$,(#11053));", "#11710=PRODUCT('Seccion intermedia','Seccion intermedia',$,(#11709));", "#12390=PRODUCT('Angulo cuadro interno','Angulo cuadro interno',$,(#12389));", "#12720=PRODUCT('Columna','Columna',$,(#12719));", "#12880=PRODUCT('Plato','Plato',$,(#12879));", "#13180=PRODUCT('Eje de la columna','Eje de la columna',$,(#13179));", "#13537=PRODUCT('Aleta refuerzo','Aleta refuerzo',$,(#13536));", "#13768=PRODUCT('Solera de esquina','Solera de esquina',$,(#13767));", "#14175=PRODUCT('Solera L interna','Solera L interna',$,(#14174));", "#14553=PRODUCT('Cartabon L','Cartabon L',$,(#14552));", "#14832=PRODUCT('Tapa ptr cruzeta','Tapa ptr cruzeta',$,(#14831));", "#15296=PRODUCT('SY 1_1_2 RM','SY 1_1_2 RM',$,(#15295));", "#15335=PRODUCT('SY 1_1_2 RM_PART1','SY 1_1_2 RM_PART1',$,(#15334));", "#22528=PRODUCT('SY 1_1_2 RM_PART2','SY 1_1_2 RM_PART2',$,(#22527));", "#23778=PRODUCT('SY 1_1_2 RM_PART3','SY 1_1_2 RM_PART3',$,(#23777));", "#24053=PRODUCT('Arreglo de mecanismo corto derecho','Arreglo de mecanismo corto derecho',$,(#24052));", "#24092=PRODUCT('Maroma','Maroma',$,(#24091));", "#24635=PRODUCT('Eje','Eje',$,(#24634));", "#24674=PRODUCT('Eje','Eje',$,(#24673));", "#25012=PRODUCT('DIN 625 SKF- con dos escudos Z SKF 6205-2Z','DIN 625 SKF- con dos escudos Z SKF 6205-2Z',$,(#25011));", "#27124=PRODUCT('Pivote flecha de giro','Pivote flecha de giro',$,(#27123));", "#27424=PRODUCT('Flecha de giro','Flecha de giro',$,(#27423));", "#27597=PRODUCT('Flecha corta','Flecha corta',$,(#27596));", "#27775=PRODUCT('Arreglo de mecanismo corto izquierdo','Arreglo de mecanismo corto izquierdo',$,(#27774));", "#27910=PRODUCT('Camino de rodillos','Camino de rodillos',$,(#27909));", "#27949=PRODUCT('Marco','Marco',$,(#27948));", "#27988=PRODUCT('Lado largo','Lado largo',$,(#27987));", "#28776=PRODUCT('Larguero','Larguero',$,(#28775));", "#29292=PRODUCT('L larga','L larga',$,(#29291));", "#29331=PRODUCT('L larga','L larga',$,(#29330));", "#29941=PRODUCT('Alojamiento U','Alojamiento U',$,(#29940));", "#30185=PRODUCT('L corta','L c ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-87c73b254e40> in <module>
#       5 test = StepParse()
#       6
# ----> 7 test.load_step(step_filename)
#       8
#       9 # test.create_tree()
#
# ~\PythonDev\GitHub\DCS-project\lib\step_parse.py in load_step(self, step_filename)
#     132                         # Add names from 'PRODUCT_DEFINITION' lines
#     133                         for i in range(len(self.prod_refs)):
# --> 134                                 if self.prod_refs[i][0] == self.prod_all_refs[j][2]:
#     135                                         self.prod_all_refs[j].append(self.prod_refs[i][2])
#     136                                         break
#
# IndexError: list index out of range

# %%
test.tree_to_json(save_to_file=True,filename='test',path='C:/Users/prctha/Desktop/')
